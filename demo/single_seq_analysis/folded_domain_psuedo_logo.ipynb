# %%
import numpy as np
import matplotlib

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
	
# Set such that PDF fonts export in a manner that they
# are editable in illustrator/affinity
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# set to define axes linewidths
matplotlib.rcParams['axes.linewidth'] = 0.5

plt.rcParams['xtick.major.size'] = 1.2  # length of major xticks
plt.rcParams['xtick.major.width'] = 0.5   # width of major xticks
plt.rcParams['ytick.major.size'] = 1.2  # length of major yticks
plt.rcParams['ytick.major.width'] = 0.5   # width of major yticks


# this defines some prefactors so inline figures look nice
# on a retina macbook. These can be commented out without any
# issue and are solely asthetic.
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# UPDATE 2020-12-31 (my preferred font is Avenir...)
font = {'family' : 'avenir',
    	'weight' : 'normal'}

matplotlib.rc('font', **font)

from tqdm import tqdm
import pickle
from sparrow import Protein
from matplotlib.colors import LogNorm

from sparrow.predictors import batch_predict
# Out:
# Error importing GPy.
#  If trying to run parrot-optimize, make sure to use `pip install idptools-parrot[optimize]`

# %%
from finches.utils import folded_domain_utils
from finches.frontend.interlogo import  display_protein_interaction_logo_visualization
import mdtraj as md
from finches import Mpipi_frontend
from finches  import CALVADOS_frontend
mf = Mpipi_frontend()
cf = CALVADOS_frontend()
# Out:
# /Users/nrazo/Packages/finches/finches/forcefields/calvados.py:235: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.038286503882254706' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   r.loc['H','q'] = 1. / ( 1 + 10**(self.pH-6) )

# %%
# clean up so numbering is easy
RECLEAN_NUMBERS = False

if RECLEAN_NUMBERS:
    folded_domain_utils.extract_and_write_domains('ABD_frame0.pdb', 'ABD_frame0_renumbered.pdb', start=0, end=80)

# %%
# load in a folded structure of Gal11 (158-238)
FD = folded_domain_utils.FoldeDomain('ABD_frame0_renumbered.pdb',surface_thresh=0.1, sasa_mode='v1')

FD.write_SASA_vis_file('ABD_sasa.txt')

# %% [markdown]
# ## Lets display the protein surface logo to show that there is averaging that is occuring

# %% [markdown]
# Without visualizing this exteriorly, there is not much we can check. But we can check that the code is giving back something that matches expectations. We expect that we will get back data that has been averaged in some manner. So we will look for this.

# %%
logo_res = FD.get_patch_sequence_logo(mf.IMC_object, 12.1, 3.4, 0.0)
display_protein_interaction_logo_visualization(*logo_res)
# Out:
# <table style='border-collapse: collapse; margin: auto; border: 1px solid #ccc;'><tr style='border-bottom: 1px dashed #ccc;'><td style='padding: 0; border-left: 1px solid #f0f0f0; border-right: 1px solid #f0f0f0; background-color: transparent; vertical-align: bottom;'><div style="width: 25.00px; margin: 0 auto; line-height: 0; font-size: 0;">
#         <div style="
#             height: 16.79px;
#             width: 100%;
#             color: #ff9d00;
#             font-family: 'Consolas', 'Menlo', 'Courier New', monospace';
#             font-weight: bold;
#             font-size: 13.43px;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             overflow: hidden;
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         ">W</div>
#         <div style="
#             height: 13.60px;
#             width: 100%;
#             color: #ff9d00;
#             font-family: 'Consolas', 'Menlo', 'Courier New', monospace';
#             font-weight: bold;
#             font-size: 10.88px;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             overflow: hidden;
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         ">Y</div>
#         <div style="
#             height: 12.91px;
#             width: 100%;
#             color: #ff0d0d;
#             font-family: 'Consolas', 'Menlo', 'Courier New', monospace';
#             font-weight: bold;
#             font-size: 10.33px;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             overflow: hidden;
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         ">E</div>
#         <div style="
#             height: 12.84px;
#             width: 100%;
#             color: #ff0d0d;
#             font-family: 'Consolas', 'Menlo', 'Courier New', monospace';
#             font-weight: bold;
#             font-size: 10.27px;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             overflow: hidden;
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         ">D</div>
#         <div style="
#             height: 12.81px;
#             width: 100%;
#             color: #ff9d00;
#             font-family: 'Consolas', 'Menlo', 'Courier New', monospace';
#             font-weight: bold;
#             font-size: 10.25px;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             overflow: hidden;
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         ">F</div>
#         <div style="
#             height: 9.04px;
#             width: 100%;
#             color: #04700d;
#             font-family: 'Consolas', 'Menlo', 'Courier New', monospace';
#             font-weight: bold;
#             font-size: 8.00px;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             overflow: hidden;
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         ">Q</div>
#         <div style="
#             height: 8.65px;
#             width: 100%;
#             color: #04700d;
#             font-family: 'Consolas', 'Menlo', 'Courier New', monospace';
#             font-weight: bold;
#             font-size: 8.00px;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             overflow: hidden;
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         ">N</div>
#         <div style="
#             height: 8.17px;
#             width: 100%;
#             color: #cf30b7;
#             font-family: 'Consolas', 'Menlo', 'Courier New', monospace';
#             font-weight: bold;
#             font-size: 8.00px;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             overflow: hidden;
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         ">P</div>
#         <div style="
#             height: 8.09px;
#             width: 100%;
#             color: #04700d;
#             font-family: 'Consolas', 'Menlo', 'Courier New', monospace';
#             font-weight: bold;
#             font-size: 8.00px;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             overflow: hidden;
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         ">H</div>
#         <div style="
#             height: 5.92px;
#             width: 100%;
#             color: #04700d;
#             font-family: 'Consolas', 'Menlo', 'Courier New', monospace';
#             font-weight: bold;
#             font-size: 8.00px;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             overflow: hidden;
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         ">G</div>
#         <div style="
#             height: 5.91px;
#             width: 100%;
#             color: #ffe70d;
#             font-family: 'Consolas', 'Menlo', 'Courier New', monospace';
#             font-weight: bold;
#             font-size: 8.00px;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             overflow: hidden;
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         ">C</div>
#         <div style="
#             height: 5.61px;
#             width: 100%;
#             color: #171616;
#             font-family: 'Consolas', 'Menlo', 'Courier New', monospace';
#             font-weight: bold;
#             font-size: 8.00px;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             overflow: hidden;
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         ">M</div>
#         <div style="
#             height: 5.60px;
#             width: 100%;
#             color: #04700d;
#             font-family: 'Consolas', 'Menlo', 'Courier New', monospace';
#             font-weight: bold;
#             font-size: 8.00px;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             overflow: hidden;
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         ">S</div>
#         <div style="
#             height: 5.29px;
#             width: 100%;
#             color: #171616;
#             font-family: 'Consolas', 'Menlo', 'Courier New', monospace';
#             font-weight: bold;
#             font-size: 8.00px;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             overflow: hidden;
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         ">A</div>
#         <div style="
#             height: 5.17px;
#             width: 100%;
#             color: #04700d;
#             font-family: 'Consolas', 'Menlo', 'Courier New', monospace';
#             font-weight: bold;
#             font-size: 8.00px;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             overflow: hidden;
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         ">T</div>
#         <div style="
#             height: 4.98px;
#             width: 100%;
#             color: #171616;
#             font-family: 'Consolas', 'Menlo', 'Courier New', monospace';
#             font-weight: bold;
#             font-size: 8.00px;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             overflow: hidden;
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         ">L</div>
#         <div style="
#             height: 4.74px;
#             width: 100%;
#             color: #171616;
#             font-family: 'Consolas', 'Menlo', 'Courier New', monospace';
#             font-weight: bold;
